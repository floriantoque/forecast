# %%
import pandas as pd
import numpy as np
import os
try:
    import cPickle as pickle
except:
    import pickle
import json
import itertools
import time

# %%
# use cpu if model with loop
#import os
#os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
#os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from keras.layers import *
from keras.models import Model,load_model
from keras.models import model_from_json
from keras.callbacks import EarlyStopping
import keras.backend as K
#K.set_session(K.tf.Session(config=K.tf.ConfigProto(intra_op_parallelism_threads=3, inter_op_parallelism_threads=3)))
# Out:
# Using TensorFlow backend.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
mpl.rcParams['figure.figsize'] = (16,8)

# %% [markdown]
# # Prediction t+15min des entrants  / stations
# ## (RER / metro / tram / train de banlieue)
#
# Objectifs :
# - mettre au point tester architecture de RNN
# - influence du contexte (variable calendaire)
# - prise en compte des serie temporelle voisines
#
# Données :
# - ensemble d'apprentissage 2014 (cross-validation 80/20)
# - ensemble de test 4 trimestre de 2015
# - 30 stations autour du pole de la défense

# %% [markdown]
#  * [Model multi](#modelmulti)
#  * [Model uni](#modeluni)
#  * [Model fusion](#modelfusion)

# %%
# model dense
def create_xy_dense(X, look_back=100):
    dataX, dataY = [], []
    for i in range(len(X)-look_back):
        y = X[i+look_back]
        x = X[i:(i+look_back)]
        dataX.append(x)
        dataY.append(y)
    return np.array(dataX), np.array(dataY)

# model time distributed dense
def create_xy_jump(X, look_back=100):
    dataX, dataY = [], []
    for i in range(len(X)-look_back):
        y = X[i+1:i+look_back+1]
        x = X[i:(i+look_back)]
        dataX.append(x)
        dataY.append(y)
    return np.array(dataX), np.array(dataY)

# model time distributed dense with end data
def create_xy_jump_end(X, look_back=100):
    #len(X)-1 because prediction timestep+1
    n = int(np.floor((len(X)-1)/look_back)*look_back+1)
    diff=len(X)-n

    try:
        dataX = np.reshape(X[diff+0:(n+diff-1),:],((n/look_back),look_back,X.shape[1]))
        dataY = np.reshape(X[diff+1:n+diff,:],((n/look_back),look_back,X.shape[1]))
    except:
        print("WARNING date?")
        dataX = np.reshape(X[diff+0:(n+diff-1)],((n/look_back),look_back))
        dataY = np.reshape(X[diff+1:n+diff],((n/look_back),look_back))
    
    return np.array(dataX), np.array(dataY)

# %%
def yes_or_no(question):
    while "the answer is invalid":
        reply = str(input(question+' (y/n): ')).lower().strip()
        if reply[:1] == 'y':
            return True
        if reply[:1] == 'n':
            return False
        
def PickleRick(path,name,obj,force=False):
    if force:
        try:
            with open(path+name, 'wb') as f:
                pickle.dump(obj, f)
        except:
            os.makedirs(path)
            with open(path+name, 'wb') as f:
                pickle.dump(obj, f)
    else:
        try:
            if os.path.isfile(path+name):
                if yes_or_no("Do you want to erase file : "+path+name):
                    with open(path+name, 'wb') as f:
                        pickle.dump(obj, f)
            else:
                with open(path+name, 'wb') as f:
                    pickle.dump(obj, f)
        except:
            os.makedirs(path)
            if os.path.isfile(path+name):
                if yes_or_no("Do you want to erase file : "+path+name):
                    with open(path+name, 'wb') as f:
                        pickle.dump(obj, f)
            else:
                with open(path+name, 'wb') as f:
                    pickle.dump(my_model, f)

# %% [markdown]
# # MAIN

# %%
# lecture de données
#path_vals = "../../../../data/data_clean/validation/final_data/station_valid_clean267_15min_fermoins5_1_shift_nofree_norenovation.csv"
#path_cont = "../../../../data/data_clean/date/2013-01-01-2019-01-01_new.csv"
#path_info = "../../../../data/data_clean/station/final_data/station_info_clean267_more_info.csv"

path_vals = "/home/toque/data2/montreal/stm/data/valid_metro_15min_2015_2016_2017_sumpass_nodayfree.csv"
path_cont = "/home/toque/data2/date/2013-01-01-2019-01-01_new.csv"
path_info = "/home/toque/data2/montreal/stm/data/station_info.csv"

Vals = pd.read_csv(path_vals)
Cont = pd.read_csv(path_cont)
Info = pd.read_csv(path_info)

# %% [markdown]
# start_date_pred = "2013-12-28"
# end_date_pred = "2016-01-01"
#
#
# # nombre de validation
# DatavPred=X[my_model['list_id_time_series']][start_date_pred:end_date_pred].values
# # variables calendaires
# DatacPred=X[my_model['list_features_timet']][start_date_pred:end_date_pred].values
# DatePred=X[my_model['list_id_time_series']][start_date_pred:end_date_pred].index.values
#
# # normalisation
# norm = my_model['norm']
# scaler = None
# if norm:
#     #scaler = my_model['scaler']
#     #DatavPredS =scaler.transform(DatavPred.astype(float))
#     DatavPredS = DatavPred/my_model['mean_train']
#
#     #DatavPredS = scaler.transform(DatavPred.astype(float))
# else:
#     DatavPredS = DatavPred
#
#
# # one hot encoder contextual values
# enc = my_model["encoder"]
# DatacPredOh = np.array(enc.transform(DatacPred).todense())
#
#
# XvPred,YvPred,XcPred,YcPred=None,None,None,None,
# XDate,YDate=None,None
# XvPred,YvPred=create_xy_dense(DatavPredS,look_back=my_model["lag_window"])
# XcPred,YcPred=create_xy_dense(DatacPredOh,look_back=my_model["lag_window"])
# XDate,YDate=create_xy_dense(DatePred,look_back=my_model["lag_window"])
# YDate=YDate.ravel()
#
# path_architecture = path_save_learning+"2014-01-01"+"_"+"2015-01-01"+"/architecture.json"
# path_weights= path_save_learning+"2014-01-01"+"_"+"2015-01-01"+"/weights.npy"
# with open(path_architecture) as data_file:
#     json_string = json.load(data_file)
#
# model_learn = model_from_json(json_string)
# model_weights = np.load(path_weights)
# model_learn.set_weights(model_weights)
#
#
# prediction = model_learn.predict([XvPred,XcPred,YcPred],verbose=1)
# prediction2 = ml.predict([XvPred,XcPred,YcPred],verbose=1)

# %% [markdown]
# (prediction !=prediction2).sum()

# %% [markdown]
# <a id='modeluni'></a>
# # MODEL UNI

# %%
def buildGRUUNI(drop, nbneurones, lag_window, len_time_series, len_context):
    vals=Input(shape=(lag_window,len_time_series,))
    xc=Input(shape=(lag_window,len_context,))
    yc=Input(shape=(len_context,))
    
    drop = Dropout(drop)(vals)
    gru  = []
    xh   = [] 
    x    = []
    xp   = []
    xpr  = []
    pred = []

    for i in range(len_time_series):
        xp.append(Lambda(lambda x:x[:,:,i])(drop)) #add values dropouted (drop) and lambda filter the station
        xpr.append(Reshape((lag_window,1))(xp[i])) #reshape dropouted values
        x.append(concatenate([xc,xpr[i]])) #add context and values
        #add gru layer with input=x
        gru.append(CuDNNGRU(nbneurones, return_sequences=False, input_shape=(lag_window, len_context+1))(x[i]))
        xh.append(concatenate([yc,gru[i]])) # add context plus gru output
        pred.append(Dense(1,activation='softplus')(xh[i]))
        
        
    predc=concatenate(pred)
    m = Model(inputs=[vals,xc,yc],outputs=predc)
    return m

# %%
#tochange
model_name="gru_dense_InUni_OutUni"
path_save_optimize="/home/toque/data2/forecast/model/gru_dense_InUni_OutUni/optimize/"+model_name+"/"
path_save_fit="/home/toque/data2/forecast/model/gru_dense_InUni_OutUni/fit/"+model_name+"/"
path_save_prediction="/home/toque/data2/forecast/model/gru_dense_InUni_OutUni/prediction/"+model_name+"/"

#tochange
time_series = ['11', '32', '34', '15', '44', '65', '31', '33', '35', '47', '13',
       '14', '1', '9', '5', '18', '36', '24', '68', '43', '8', '64', '10',
       '55', '3', '49', '51', '2', '19', '56', '7', '6', '4', '48', '66',
       '25', '23', '28', '39', '54', '60', '27', '20', '46', '12', '21',
       '62', '52', '41', '50', '30', '16', '37', '40', '26', '67', '57',
       '61', '42', '45', '38', '29', '58', '63', '22', '59', '53', '17']


features_tminuslag_t0 = ["hms_int_15min", 'Day_id', 'Mois_id','vac_noel_quebec', 'day_off_quebec', '24DEC', '31DEC',
                    'renov_beaubien', 'vac_udem1', 'vac_udem2']


ContF=Cont[["Datetime"]+features_tminuslag_t0]
X=Vals.set_index('Datetime')[time_series].join(ContF.set_index('Datetime'))
                                
# optim parameters model                     

list_drop = [0.001]
list_neurones = [100,200,300]
list_forget = [0.8]
list_epoch = [15,20,25,30,35,40]

batch_size=128
lag_window = 100

norm=True
scaler=None
n_split = 5
val_size=0.2

# %% [markdown]
# #COMPLEXITY
# with open(path_save_learning+"model_infos.pkl", 'r') as f:
#     my_model = cPickle.load(f)
#
# start_date_train_list=["2015-01-01"]
# end_date_train_list=["2017-01-01"]
#
#
# for i,j in zip(start_date_train_list, end_date_train_list):
#
#     DatavPred,DatacPred=None,None
#     XvPred,YvPred,XcPred,YcPred=None,None,None,None,
#     DatavTrain,DatacTrain=None,None
#     XvTrain,YvTrain,Xco,Yco=None,None,None,None,
#
#     DatavTrain=X[my_model['time_series']][i:j].values
#     DatacTrain=X[my_model['list_features_timet']][i:j].values
#
#     # normalisation
#     norm=my_model['norm']
#     scaler = my_model["scaler"]
#     if norm:
#         #scaler = MinMaxScaler(feature_range=[0,1])
#         #DatavTrainS = scaler.fit_transform(DatavTrain.astype(float))
#         mean_train =  DatavTrain.mean(axis=0)
#         my_model["mean_train"]=mean_train
#         DatavTrainS = DatavTrain/mean_train
#         #scaler = StandardScaler()
#        # DatavTrainS = scaler.fit_transform(DatavTrain.astype(float))
#     else:
#         DatavTrainS = DatavTrain
#
#     # one hot encoder contextual values
#     enc = my_model["encoder"]
#     DatacTrainOh = np.array(enc.transform(DatacTrain).todense())
#
#
#
#     XvTrain,YvTrain=create_xy_dense(DatavTrainS,look_back=my_model["lag_window"])
#     XcTrain,YcTrain=create_xy_dense(DatacTrainOh,look_back=my_model["lag_window"])
#
#
#
#     ml = buildGRUUNI(my_model["best_drop"] ,int(my_model["best_neurones"]), my_model["lag_window"],
#                         len(my_model["list_id_time_series"]),YcTrain.shape[1])
#     ml.compile(optimizer='adam',loss='mae',metrics=['mse','mae'],sample_weight_mode=None)
#     w = np.linspace(1,my_model["best_forget"],XvTrain.shape[0])
#     #w = np.reshape(np.repeat(np.flip(w,0),my_model['lag_window']),(w.shape[0],my_model['lag_window']))
#     h = ml.fit([XvTrain,XcTrain,YcTrain],YvTrain,epochs=1,sample_weight=w,batch_size=my_model["batch_size"])
#
# a = ml.get_weights()
# print "Nb neurones:",sum([i.size for i in a])

# %%
# creation of my model that contains information about the model
my_model={}
my_model["path_values"] = path_vals
my_model["path_context"]= path_cont
my_model["path_info"]= path_info
my_model["model_name"]= model_name
my_model["path_save_optimize"]= path_save_optimize
my_model["path_save_fit"]= path_save_fit
my_model["path_save_prediction"]= path_save_prediction
my_model["time_series"] = time_series
my_model["features_tminuslag_t0"] = features_tminuslag_t0
my_model["list_drop"] = list_drop
my_model["list_neurones"] = list_neurones
my_model["list_forget"] = list_forget
my_model["list_epoch"] = list_epoch
my_model["lag_window"] = lag_window
my_model["batch_size"] = batch_size
my_model["val_size"] = val_size
my_model['norm'] = norm
my_model["scaler"] = scaler
my_model["n_split"] = n_split
my_model["function_model"] = buildGRUUNI

enc = OneHotEncoder()
enc = enc.fit(X[features_tminuslag_t0].values)
my_model["encoder"] = enc

PickleRick(path=my_model["path_save_optimize"],name="model_infos.pkl",obj=my_model,force=True)

# %% [markdown]
# ## Optimisation UNI

# %%
with open(path_save_optimize +"model_infos.pkl", 'rb') as f:
    my_model = pickle.load(f)

# train set
start_date_train = "2015-01-01"
end_date_train = "2017-01-01"


DatavTrain=X[time_series][start_date_train:end_date_train].values
DatacTrain=X[features_tminuslag_t0][start_date_train:end_date_train].values

# normalisation

if my_model["norm"]:
    #scaler = MinMaxScaler(feature_range=[0,1])
    #DatavTrainS = scaler.fit_transform(DatavTrain.astype(float))
    #scaler = StandardScaler()
    #DatavTrainS = scaler.fit_transform(DatavTrain.astype(float))
    #my_model["scaler"]=scaler
    mean_train =  DatavTrain.mean(axis=0)
    my_model["mean_train"]=mean_train
    DatavTrainS = DatavTrain/mean_train
    
else:
    DatavTrainS = DatavTrain
    
# one hot encoder contextual values
enc = my_model["encoder"]
DatacTrainOh = np.array(enc.transform(DatacTrain).todense())

XvTrain,YvTrain,Xco,Yco=None,None,None,None,
XvTrain,YvTrain=create_xy_dense(DatavTrainS,look_back=my_model["lag_window"])
XcTrain,YcTrain=create_xy_dense(DatacTrainOh,look_back=my_model["lag_window"])


my_model["start_date_train"] = start_date_train
my_model["end_date_train"] = end_date_train


PickleRick(path=my_model["path_save_optimize"], name="model_infos.pkl",obj=my_model, force=True)

# %%
# GridSearch sur les hyperparamètres
hyperparams = [my_model["list_drop"],my_model["list_neurones"],my_model["list_forget"]]


CvGridResLoc = []
for rs in range(my_model["n_split"]):
    print ("split ",rs+1)
    Xvapp,Xvval,Yvapp,Yvval=None,None,None,None
    Xcapp,Xcval,Ycapp,Ycval=None,None,None,None
    Xvapp,Xvval,Yvapp,Yvval = train_test_split(XvTrain,YvTrain,test_size=my_model["val_size"],shuffle=True,random_state=rs)
    Xcapp,Xcval,Ycapp,Ycval = train_test_split(XcTrain,YcTrain,test_size=my_model["val_size"],shuffle=True,random_state=rs)
    #iapp =  int(np.floor(XvTrain.shape[0]*(1-((rs+1)*0.1))))
    #iplus = int(np.floor(XvTrain.shape[0]*0.1))+1
    #Xvapp,Xvval,Yvapp,Yvval = XvTrain[:iapp],XvTrain[iapp:],YvTrain[:iapp],YvTrain[iapp:]
    #Xcapp,Xcval,Ycapp,Ycval = XcTrain[:iapp],XcTrain[iapp:],YcTrain[:iapp],YcTrain[iapp:]
    
    GridResLoc = {}
    cur=1
    for config in itertools.product(*hyperparams):
        t=time.time()
        print ("model ",cur,", config: ",config)
        cur+=1
        m = buildGRUUNI(config[0],config[1], my_model["lag_window"],
                        len(my_model["time_series"]),Ycapp.shape[1])
        m.compile(optimizer='adam',loss='mae',metrics=['mse','mae'],sample_weight_mode=None)
        w = np.linspace(1,config[2],XvTrain.shape[0])
        #w = np.reshape(np.repeat(np.flip(w,0),my_model['lag_window']),(w.shape[0],my_model['lag_window']))

        #w = np.reshape(np.repeat(np.flip(w,0),my_model["lag_window"]),(w.shape[0],my_model["lag_window"]))
        wapp,wval = train_test_split(w,test_size=my_model["val_size"],shuffle=True,random_state=rs)
        #wapp,wval = w[:iapp],w[iapp:]

        h = m.fit([Xvapp,Xcapp,Ycapp],Yvapp,epochs=max(my_model['list_epoch']),
                  validation_data=([Xvval,Xcval,Ycval], Yvval),sample_weight=wapp,batch_size=my_model["batch_size"])
        
        for nbe in my_model['list_epoch']:
            GridResLoc[config +(nbe,)]={'history':h.history,'mae':h.history['val_loss'][nbe-1]}
        print ("time: ",time.time()-t    )
    CvGridResLoc.append(GridResLoc)

    PickleRick(path=my_model["path_save_optimize"],name="cvgridsearch.pkl",obj=CvGridResLoc,force=True)
# Out:
# split  1
# model  1 , config:  (0.001, 100, 0.8)
# Train on 519 samples, validate on 130 samples
# Epoch 1/40
# 519/519 [==============================] - 2s 4ms/step - loss: 0.6709 - mean_squared_error: 1.4268 - mean_absolute_error: 0.7615 - val_loss: 0.6941 - val_mean_squared_error: 1.3963 - val_mean_absolute_error: 0.6941
# Epoch 2/40
# 519/519 [==============================] - 0s 429us/step - loss: 0.5898 - mean_squared_error: 1.1656 - mean_absolute_error: 0.6700 - val_loss: 0.6060 - val_mean_squared_error: 1.0536 - val_mean_absolute_error: 0.6060
# Epoch 3/40
# 519/519 [==============================] - 0s 331us/step - loss: 0.4836 - mean_squared_error: 0.7584 - mean_absolute_error: 0.5483 - val_loss: 0.5393 - val_mean_squared_error: 0.6762 - val_mean_absolute_error: 0.5393
# Epoch 4/40
# 519/519 [==============================] - 0s 339us/step - loss: 0.3934 - mean_squared_error: 0.4544 - mean_absolute_error: 0.4458 - val_loss: 0.4062 - val_mean_squared_error: 0.4759 - val_mean_absolute_error: 0.4062
# Epoch 5/40
# 519/519 [==============================] - 0s 314us/step - loss: 0.3260 - mean_squared_error: 0.3348 - mean_absolute_error: 0.3695 - val_loss: 0.3394 - val_mean_squared_error: 0.3428 - val_mean_absolute_error: 0.3394
# Epoch 6/40
# 519/519 [==============================] - 0s 290us/step - loss: 0.2803 - mean_squared_error: 0.2339 - mean_absolute_error: 0.3179 - val_loss: 0.2941 - val_mean_squared_error: 0.2230 - val_mean_absolute_error: 0.2941
# Epoch 7/40
# 519/519 [==============================] - 0s 238us/step - loss: 0.2479 - mean_squared_error: 0.1873 - mean_absolute_error: 0.2823 - val_loss: 0.2488 - val_mean_squared_error: 0.2034 - val_mean_absolute_error: 0.2488
# Epoch 8/40
# 519/519 [==============================] - 0s 221us/step - loss: 0.2112 - mean_squared_error: 0.1478 - mean_absolute_error: 0.2400 - val_loss: 0.2381 - val_mean_squared_error: 0.1999 - val_mean_absolute_error: 0.2381
# Epoch 9/40
# 519/519 [==============================] - 0s 216us/step - loss: 0.1911 - mean_squared_error: 0.1346 - mean_absolute_error: 0.2170 - val_loss: 0.2432 - val_mean_squared_error: 0.2009 - val_mean_absolute_error: 0.2432
# Epoch 10/40
# 519/519 [==============================] - 0s 215us/step - loss: 0.1818 - mean_squared_error: 0.1219 - mean_absolute_error: 0.2061 - val_loss: 0.2193 - val_mean_squared_error: 0.1747 - val_mean_absolute_error: 0.2193
# Epoch 11/40
# 519/519 [==============================] - 0s 211us/step - loss: 0.1729 - mean_squared_error: 0.1184 - mean_absolute_error: 0.1958 - val_loss: 0.2057 - val_mean_squared_error: 0.1588 - val_mean_absolute_error: 0.2057
# Epoch 12/40
# 519/519 [==============================] - 0s 208us/step - loss: 0.1624 - mean_squared_error: 0.0998 - mean_absolute_error: 0.1840 - val_loss: 0.2035 - val_mean_squared_error: 0.1585 - val_mean_absolute_error: 0.2035
# Epoch 13/40
# 519/519 [==============================] - 0s 205us/step - loss: 0.1605 - mean_squared_error: 0.0975 - mean_absolute_error: 0.1820 - val_loss: 0.2003 - val_mean_squared_error: 0.1463 - val_mean_absolute_error: 0.2003
# Epoch 14/40
# 519/519 [==============================] - 0s 198us/step - loss: 0.1580 - mean_squared_error: 0.0905 - mean_absolute_error: 0.1790 - val_loss: 0.1965 - val_mean_squared_error: 0.1467 - val_mean_absolute_error: 0.1965
# Epoch 15/40
# 519/519 [==============================] - 0s 195us/step - loss: 0.1523 - mean_squared_error: 0.0871 - mean_absolute_error: 0.1723 - val_loss: 0.1955 - val_mean_squared_error: 0.1387 - val_mean_absolute_error: 0.1955
# Epoch 16/40
# 519/519 [==============================] - 0s 197us/step - loss: 0.1515 - mean_squared_error: 0.0813 - mean_absolute_error: 0.1709 - val_loss: 0.1869 - val_mean_squared_error: 0.1308 - val_mean_absolute_error: 0.1869
# Epoch 17/40
# 519/519 [==============================] - 0s 199us/step - loss: 0.1443 - mean_squared_error: 0.0791 - mean_absolute_error: 0.1631 - val_loss: 0.1841 - val_mean_squared_error: 0.1256 - val_mean_absolute_error: 0.1841
# Epoch 18/40
# 519/519 [==============================] - 0s 205us/step - loss: 0.1427 - mean_squared_error: 0.0757 - mean_absolute_error: 0.1611 - val_loss: 0.1827 - val_mean_squared_error: 0.1246 - val_mean_absolute_error: 0.1827
# Epoch 19/40
# 519/519 [==============================] - 0s 206us/step - loss: 0.1410 - mean_squared_error: 0.0813 - mean_absolute_error: 0.1592 - val_loss: 0.1866 - val_mean_squared_error: 0.1259 - val_mean_absolute_error: 0.1866
# Epoch 20/40
# 519/519 [==============================] - 0s 206us/step - loss: 0.1414 - mean_squared_error: 0.0785 - mean_absolute_error: 0.1599 - val_loss: 0.1816 - val_mean_squared_error: 0.1251 - val_mean_absolute_error: 0.1816
# Epoch 21/40
# 519/519 [==============================] - 0s 207us/step - loss: 0.1446 - mean_squared_error: 0.0779 - mean_absolute_error: 0.1630 - val_loss: 0.1851 - val_mean_squared_error: 0.1245 - val_mean_absolute_error: 0.1851
# Epoch 22/40
# 519/519 [==============================] - 0s 197us/step - loss: 0.1443 - mean_squared_error: 0.0747 - mean_absolute_error: 0.1632 - val_loss: 0.1802 - val_mean_squared_error: 0.1220 - val_mean_absolute_error: 0.1802
# Epoch 23/40
# 519/519 [==============================] - 0s 193us/step - loss: 0.1359 - mean_squared_error: 0.0758 - mean_absolute_error: 0.1535 - val_loss: 0.1803 - val_mean_squared_error: 0.1276 - val_mean_absolute_error: 0.1803
# Epoch 24/40
# 519/519 [==============================] - 0s 194us/step - loss: 0.1327 - mean_squared_error: 0.0734 - mean_absolute_error: 0.1501 - val_loss: 0.1878 - val_mean_squared_error: 0.1139 - val_mean_absolute_error: 0.1878
# Epoch 25/40
# 519/519 [==============================] - 0s 196us/step - loss: 0.1364 - mean_squared_error: 0.0696 - mean_absolute_error: 0.1538 - val_loss: 0.1767 - val_mean_squared_error: 0.1142 - val_mean_absolute_error: 0.1767
# Epoch 26/40
# 519/519 [==============================] - 0s 198us/step - loss: 0.1339 - mean_squared_error: 0.0712 - mean_absolute_error: 0.1515 - val_loss: 0.1757 - val_mean_squared_error: 0.1163 - val_mean_absolute_error: 0.1757
# Epoch 27/40
# 519/519 [==============================] - 0s 196us/step - loss: 0.1358 - mean_squared_error: 0.0728 - mean_absolute_error: 0.1536 - val_loss: 0.1842 - val_mean_squared_error: 0.1142 - val_mean_absolute_error: 0.1842
# Epoch 28/40
# 519/519 [==============================] - 0s 195us/step - loss: 0.1454 - mean_squared_error: 0.0761 - mean_absolute_error: 0.1641 - val_loss: 0.1767 - val_mean_squared_error: 0.1188 - val_mean_absolute_error: 0.1767
# Epoch 29/40
# 519/519 [==============================] - 0s 195us/step - loss: 0.1380 - mean_squared_error: 0.0807 - mean_absolute_error: 0.1562 - val_loss: 0.1761 - val_mean_squared_error: 0.1123 - val_mean_absolute_error: 0.1761
# Epoch 30/40
# 519/519 [==============================] - 0s 195us/step - loss: 0.1314 - mean_squared_error: 0.0665 - mean_absolute_error: 0.1483 - val_loss: 0.1742 - val_mean_squared_error: 0.1121 - val_mean_absolute_error: 0.1742
# Epoch 31/40
# 519/519 [==============================] - 0s 196us/step - loss: 0.1285 - mean_squared_error: 0.0671 - mean_absolute_error: 0.1452 - val_loss: 0.1791 - val_mean_squared_error: 0.1094 - val_mean_absolute_error: 0.1791
# Epoch 32/40
# 519/519 [==============================] - 0s 197us/step - loss: 0.1245 - mean_squared_error: 0.0615 - mean_absolute_error: 0.1408 - val_loss: 0.1808 - val_mean_squared_error: 0.1051 - val_mean_absolute_error: 0.1808
# Epoch 33/40
# 519/519 [==============================] - 0s 198us/step - loss: 0.1336 - mean_squared_error: 0.0656 - mean_absolute_error: 0.1508 - val_loss: 0.1750 - val_mean_squared_error: 0.1123 - val_mean_absolute_error: 0.1750
# Epoch 34/40
# 519/519 [==============================] - 0s 197us/step - loss: 0.1278 - mean_squared_error: 0.0690 - mean_absolute_error: 0.1446 - val_loss: 0.1776 - val_mean_squared_error: 0.1114 - val_mean_absolute_error: 0.1776
# Epoch 35/40
# 519/519 [==============================] - 0s 197us/step - loss: 0.1265 - mean_squared_error: 0.0611 - mean_absolute_error: 0.1427 - val_loss: 0.1742 - val_mean_squared_error: 0.1032 - val_mean_absolute_error: 0.1742
# Epoch 36/40
# 519/519 [==============================] - 0s 198us/step - loss: 0.1248 - mean_squared_error: 0.0640 - mean_absolute_error: 0.1412 - val_loss: 0.1739 - val_mean_squared_error: 0.1128 - val_mean_absolute_error: 0.1739
# Epoch 37/40
# 519/519 [==============================] - 0s 198us/step - loss: 0.1228 - mean_squared_error: 0.0626 - mean_absolute_error: 0.1389 - val_loss: 0.1756 - val_mean_squared_error: 0.1055 - val_mean_absolute_error: 0.1756
# Epoch 38/40
# 519/519 [==============================] - 0s 198us/step - loss: 0.1200 - mean_squared_error: 0.0592 - mean_absolute_error: 0.1357 - val_loss: 0.1712 - val_mean_squared_error: 0.1093 - val_mean_absolute_error: 0.1712
# Epoch 39/40
# 519/519 [==============================] - 0s 198us/step - loss: 0.1246 - mean_squared_error: 0.0654 - mean_absolute_error: 0.1411 - val_loss: 0.1701 - val_mean_squared_error: 0.1122 - val_mean_absolute_error: 0.1701
# Epoch 40/40
# 519/519 [==============================] - 0s 200us/step - loss: 0.1198 - mean_squared_error: 0.0604 - mean_absolute_error: 0.1355 - val_loss: 0.1696 - val_mean_squared_error: 0.1037 - val_mean_absolute_error: 0.1696
# time:  9.99464225769043
# model  2 , config:  (0.001, 200, 0.8)
# Train on 519 samples, validate on 130 samples
# Epoch 1/40
# 519/519 [==============================] - 1s 1ms/step - loss: 0.6689 - mean_squared_error: 1.4336 - mean_absolute_error: 0.7599 - val_loss: 0.6499 - val_mean_squared_error: 1.1169 - val_mean_absolute_error: 0.6499
# Epoch 2/40
# 519/519 [==============================] - 0s 237us/step - loss: 0.4989 - mean_squared_error: 0.7482 - mean_absolute_error: 0.5641 - val_loss: 0.4719 - val_mean_squared_error: 0.6364 - val_mean_absolute_error: 0.4719
# Epoch 3/40
# 519/519 [==============================] - 0s 238us/step - loss: 0.3621 - mean_squared_error: 0.4262 - mean_absolute_error: 0.4108 - val_loss: 0.3980 - val_mean_squared_error: 0.3891 - val_mean_absolute_error: 0.3980
# Epoch 4/40
# 519/519 [==============================] - 0s 238us/step - loss: 0.3192 - mean_squared_error: 0.3156 - mean_absolute_error: 0.3637 - val_loss: 0.3114 - val_mean_squared_error: 0.2913 - val_mean_absolute_error: 0.3114
# Epoch 5/40
# 519/519 [==============================] - 0s 241us/step - loss: 0.2563 - mean_squared_error: 0.2135 - mean_absolute_error: 0.2907 - val_loss: 0.2634 - val_mean_squared_error: 0.2240 - val_mean_absolute_error: 0.2634
# Epoch 6/40
# 519/519 [==============================] - 0s 241us/step - loss: 0.2093 - mean_squared_error: 0.1364 - mean_absolute_error: 0.2371 - val_loss: 0.2409 - val_mean_squared_error: 0.1725 - val_mean_absolute_error: 0.2409
# Epoch 7/40
# 519/519 [==============================] - 0s 243us/step - loss: 0.1878 - mean_squared_error: 0.1256 - mean_absolute_error: 0.2129 - val_loss: 0.2216 - val_mean_squared_error: 0.1624 - val_mean_absolute_error: 0.2216
# Epoch 8/40
# 519/519 [==============================] - 0s 240us/step - loss: 0.1734 - mean_squared_error: 0.1071 - mean_absolute_error: 0.1968 - val_loss: 0.2112 - val_mean_squared_error: 0.1477 - val_mean_absolute_error: 0.2112
# Epoch 9/40
# 519/519 [==============================] - 0s 242us/step - loss: 0.1633 - mean_squared_error: 0.1005 - mean_absolute_error: 0.1851 - val_loss: 0.2055 - val_mean_squared_error: 0.1539 - val_mean_absolute_error: 0.2055
# Epoch 10/40
# 519/519 [==============================] - 0s 240us/step - loss: 0.1560 - mean_squared_error: 0.0932 - mean_absolute_error: 0.1766 - val_loss: 0.2038 - val_mean_squared_error: 0.1333 - val_mean_absolute_error: 0.2038
# Epoch 11/40
# 519/519 [==============================] - 0s 241us/step - loss: 0.1600 - mean_squared_error: 0.0851 - mean_absolute_error: 0.1810 - val_loss: 0.2101 - val_mean_squared_error: 0.1585 - val_mean_absolute_error: 0.2101
# Epoch 12/40
# 519/519 [==============================] - 0s 234us/step - loss: 0.1623 - mean_squared_error: 0.1010 - mean_absolute_error: 0.1838 - val_loss: 0.2028 - val_mean_squared_error: 0.1328 - val_mean_absolute_error: 0.2028
# Epoch 13/40
# 519/519 [==============================] - 0s 237us/step - loss: 0.1608 - mean_squared_error: 0.0847 - mean_absolute_error: 0.1818 - val_loss: 0.1890 - val_mean_squared_error: 0.1191 - val_mean_absolute_error: 0.1890
# Epoch 14/40
# 519/519 [==============================] - 0s 247us/step - loss: 0.1550 - mean_squared_error: 0.0823 - mean_absolute_error: 0.1750 - val_loss: 0.1840 - val_mean_squared_error: 0.1312 - val_mean_absolute_error: 0.1840
# Epoch 15/40
# 519/519 [==============================] - 0s 243us/step - loss: 0.1404 - mean_squared_error: 0.0756 - mean_absolute_error: 0.1585 - val_loss: 0.1882 - val_mean_squared_error: 0.1255 - val_mean_absolute_error: 0.1882
# Epoch 16/40
# 519/519 [==============================] - 0s 241us/step - loss: 0.1378 - mean_squared_error: 0.0779 - mean_absolute_error: 0.1556 - val_loss: 0.1800 - val_mean_squared_error: 0.1300 - val_mean_absolute_error: 0.1800
# Epoch 17/40
# 519/519 [==============================] - 0s 244us/step - loss: 0.1394 - mean_squared_error: 0.0735 - mean_absolute_error: 0.1576 - val_loss: 0.1869 - val_mean_squared_error: 0.1035 - val_mean_absolute_error: 0.1869
# Epoch 18/40
# 519/519 [==============================] - 0s 250us/step - loss: 0.1473 - mean_squared_error: 0.0710 - mean_absolute_error: 0.1666 - val_loss: 0.1704 - val_mean_squared_error: 0.1049 - val_mean_absolute_error: 0.1704
- mean_squared_error: 0.0504 - mean_absolute_error: 0.1263 - val_loss: 0.1565 - val_mean_squared_error: 0.0742 - val_mean_absolute_error: 0.1565
# Epoch 34/40
# 519/519 [==============================] - 0s 249us/step - loss: 0.1144 - mean_squared_error: 0.0499 - mean_absolute_error: 0.1289 - val_loss: 0.1634 - val_mean_squared_error: 0.0768 - val_mean_absolute_error: 0.1634
# Epoch 35/40
# 519/519 [==============================] - 0s 249us/step - loss: 0.1127 - mean_squared_error: 0.0499 - mean_absolute_error: 0.1271 - val_loss: 0.1564 - val_mean_squared_error: 0.0792 - val_mean_absolute_error: 0.1564
# Epoch 36/40
# 519/519 [==============================] - 0s 247us/step - loss: 0.1111 - mean_squared_error: 0.0486 - mean_absolute_error: 0.1254 - val_loss: 0.1579 - val_mean_squared_error: 0.0735 - val_mean_absolute_error: 0.1579
# Epoch 37/40
# 519/519 [==============================] - 0s 248us/step - loss: 0.1084 - mean_squared_error: 0.0471 - mean_absolute_error: 0.1223 - val_loss: 0.1515 - val_mean_squared_error: 0.0754 - val_mean_absolute_error: 0.1515
# Epoch 38/40
# 519/519 [==============================] - 0s 248us/step - loss: 0.1077 - mean_squared_error: 0.0468 - mean_absolute_error: 0.1216 - val_loss: 0.1519 - val_mean_squared_error: 0.0708 - val_mean_absolute_error: 0.1519
# Epoch 39/40
# 519/519 [==============================] - 0s 252us/step - loss: 0.1105 - mean_squared_error: 0.0485 - mean_absolute_error: 0.1249 - val_loss: 0.1580 - val_mean_squared_error: 0.0735 - val_mean_absolute_error: 0.1580
# Epoch 40/40
# 519/519 [==============================] - 0s 254us/step - loss: 0.1104 - mean_squared_error: 0.0461 - mean_absolute_error: 0.1245 - val_loss: 0.1526 - val_mean_squared_error: 0.0716 - val_mean_absolute_error: 0.1526
# time:  6.50493049621582
# model  3 , config:  (0.001, 300, 0.8)
# Train on 519 samples, validate on 130 samples
# Epoch 1/40
# 519/519 [==============================] - 1s 2ms/step - loss: 0.6302 - mean_squared_error: 1.2791 - mean_absolute_error: 0.7145 - val_loss: 0.5068 - val_mean_squared_error: 0.7518 - val_mean_absolute_error: 0.5068
# Epoch 2/40
# 519/519 [==============================] - 0s 315us/step - loss: 0.3824 - mean_squared_error: 0.4908 - mean_absolute_error: 0.4338 - val_loss: 0.3474 - val_mean_squared_error: 0.3173 - val_mean_absolute_error: 0.3474
# Epoch 3/40
# 519/519 [==============================] - 0s 316us/step - loss: 0.2853 - mean_squared_error: 0.2542 - mean_absolute_error: 0.3237 - val_loss: 0.3384 - val_mean_squared_error: 0.2416 - val_mean_absolute_error: 0.3384
# Epoch 4/40
# 519/519 [==============================] - 0s 338us/step - loss: 0.2483 - mean_squared_error: 0.1646 - mean_absolute_error: 0.2804 - val_loss: 0.2770 - val_mean_squared_error: 0.2029 - val_mean_absolute_error: 0.2770
# Epoch 5/40
# 519/519 [==============================] - 0s 332us/step - loss: 0.2036 - mean_squared_error: 0.1345 - mean_absolute_error: 0.2307 - val_loss: 0.2427 - val_mean_squared_error: 0.1388 - val_mean_absolute_error: 0.2427
# Epoch 6/40
# 519/519 [==============================] - 0s 324us/step - loss: 0.2002 - mean_squared_error: 0.1229 - mean_absolute_error: 0.2273 - val_loss: 0.2181 - val_mean_squared_error: 0.1445 - val_mean_absolute_error: 0.2181
# Epoch 7/40
# 519/519 [==============================] - 0s 324us/step - loss: 0.1822 - mean_squared_error: 0.1154 - mean_absolute_error: 0.2059 - val_loss: 0.2268 - val_mean_squared_error: 0.1512 - val_mean_absolute_error: 0.2268
# Epoch 8/40
# 519/519 [==============================] - 0s 321us/step - loss: 0.1780 - mean_squared_error: 0.0946 - mean_absolute_error: 0.2013 - val_loss: 0.2060 - val_mean_squared_error: 0.1224 - val_mean_absolute_error: 0.2060
# Epoch 9/40
# 519/519 [==============================] - 0s 326us/step - loss: 0.1599 - mean_squared_error: 0.0845 - mean_absolute_error: 0.1809 - val_loss: 0.1967 - val_mean_squared_error: 0.1211 - val_mean_absolute_error: 0.1967
# Epoch 10/40
# 519/519 [==============================] - 0s 326us/step - loss: 0.1555 - mean_squared_error: 0.0835 - mean_absolute_error: 0.1759 - val_loss: 0.1900 - val_mean_squared_error: 0.1137 - val_mean_absolute_error: 0.1900
# Epoch 11/40
# 519/519 [==============================] - 0s 330us/step - loss: 0.1520 - mean_squared_error: 0.0804 - mean_absolute_error: 0.1717 - val_loss: 0.1920 - val_mean_squared_error: 0.1142 - val_mean_absolute_error: 0.1920
# Epoch 12/40
# 519/519 [==============================] - 0s 320us/step - loss: 0.1491 - mean_squared_error: 0.0736 - mean_absolute_error: 0.1680 - val_loss: 0.1841 - val_mean_squared_error: 0.1140 - val_mean_absolute_error: 0.1841
# Epoch 13/40
# 519/519 [==============================] - 0s 315us/step - loss: 0.1495 - mean_squared_error: 0.0821 - mean_absolute_error: 0.1690 - val_loss: 0.1943 - val_mean_squared_error: 0.1379 - val_mean_absolute_error: 0.1943
# Epoch 14/40
# 519/519 [==============================] - 0s 318us/step - loss: 0.1473 - mean_squared_error: 0.0829 - mean_absolute_error: 0.1663 - val_loss: 0.1870 - val_mean_squared_error: 0.1162 - val_mean_absolute_error: 0.1870
# Epoch 15/40
# 519/519 [==============================] - 0s 319us/step - loss: 0.1363 - mean_squared_error: 0.0705 - mean_absolute_error: 0.1540 - val_loss: 0.1789 - val_mean_squared_error: 0.1151 - val_mean_absolute_error: 0.1789
# Epoch 16/40
# 519/519 [==============================] - 0s 318us/step - loss: 0.1346 - mean_squared_error: 0.0668 - mean_absolute_error: 0.1521 - val_loss: 0.1805 - val_mean_squared_error: 0.1025 - val_mean_absolute_error: 0.1805
# Epoch 17/40
# 519/519 [==============================] - 0s 317us/step - loss: 0.1332 - mean_squared_error: 0.0656 - mean_absolute_error: 0.1505 - val_loss: 0.1761 - val_mean_squared_error: 0.1055 - val_mean_absolute_error: 0.1761
# Epoch 18/40
# Epoch 32/40
# 519/519 [==============================] - 0s 339us/step - loss: 0.1159 - mean_squared_error: 0.0494 - mean_absolute_error: 0.1309 - val_loss: 0.1630 - val_mean_squared_error: 0.0812 - val_mean_absolute_error: 0.1630
# Epoch 33/40
# 519/519 [==============================] - 0s 336us/step - loss: 0.1120 - mean_squared_error: 0.0496 - mean_absolute_error: 0.1266 - val_loss: 0.1724 - val_mean_squared_error: 0.0874 - val_mean_absolute_error: 0.1724
# Epoch 34/40
# 519/519 [==============================] - 0s 323us/step - loss: 0.1178 - mean_squared_error: 0.0479 - mean_absolute_error: 0.1325 - val_loss: 0.1654 - val_mean_squared_error: 0.0897 - val_mean_absolute_error: 0.1654
# Epoch 35/40
# 519/519 [==============================] - 0s 315us/step - loss: 0.1104 - mean_squared_error: 0.0475 - mean_absolute_error: 0.1245 - val_loss: 0.1601 - val_mean_squared_error: 0.0765 - val_mean_absolute_error: 0.1601
# Epoch 36/40
# 519/519 [==============================] - 0s 316us/step - loss: 0.1086 - mean_squared_error: 0.0460 - mean_absolute_error: 0.1226 - val_loss: 0.1560 - val_mean_squared_error: 0.0810 - val_mean_absolute_error: 0.1560
# Epoch 37/40
# 519/519 [==============================] - 0s 325us/step - loss: 0.1055 - mean_squared_error: 0.0450 - mean_absolute_error: 0.1190 - val_loss: 0.1562 - val_mean_squared_error: 0.0749 - val_mean_absolute_error: 0.1562
# Epoch 38/40
# 519/519 [==============================] - 0s 336us/step - loss: 0.1046 - mean_squared_error: 0.0436 - mean_absolute_error: 0.1180 - val_loss: 0.1575 - val_mean_squared_error: 0.0721 - val_mean_absolute_error: 0.1575
# Epoch 39/40
# 519/519 [==============================] - 0s 331us/step - loss: 0.1105 - mean_squared_error: 0.0463 - mean_absolute_error: 0.1248 - val_loss: 0.1490 - val_mean_squared_error: 0.0693 - val_mean_absolute_error: 0.1490
# Epoch 40/40
# 519/519 [==============================] - 0s 322us/step - loss: 0.1040 - mean_squared_error: 0.0430 - mean_absolute_error: 0.1173 - val_loss: 0.1486 - val_mean_squared_error: 0.0705 - val_mean_absolute_error: 0.1486
# time:  8.294885635375977
# split  2
# model  1 , config:  (0.001, 100, 0.8)
# Train on 519 samples, validate on 130 samples
# Epoch 1/40
# 519/519 [==============================] - 1s 1ms/step - loss: 0.6367 - mean_squared_error: 1.3193 - mean_absolute_error: 0.7217 - val_loss: 0.7598 - val_mean_squared_error: 1.7506 - val_mean_absolute_error: 0.7598
# Epoch 2/40
# 519/519 [==============================] - 0s 199us/step - loss: 0.5675 - mean_squared_error: 1.1291 - mean_absolute_error: 0.6444 - val_loss: 0.6709 - val_mean_squared_error: 1.4202 - val_mean_absolute_error: 0.6709
# Epoch 3/40
# 519/519 [==============================] - 0s 193us/step - loss: 0.4668 - mean_squared_error: 0.7982 - mean_absolute_error: 0.5296 - val_loss: 0.5203 - val_mean_squared_error: 0.8096 - val_mean_absolute_error: 0.5203
# Epoch 4/40
# 519/519 [==============================] - 0s 192us/step - loss: 0.3880 - mean_squared_error: 0.4428 - mean_absolute_error: 0.4388 - val_loss: 0.4190 - val_mean_squared_error: 0.5182 - val_mean_absolute_error: 0.4190
# Epoch 5/40
# 519/519 [==============================] - 0s 193us/step - loss: 0.3178 - mean_squared_error: 0.3391 - mean_absolute_error: 0.3598 - val_loss: 0.4069 - val_mean_squared_error: 0.4874 - val_mean_absolute_error: 0.4069
# Epoch 6/40
# 519/519 [==============================] - 0s 196us/step - loss: 0.2883 - mean_squared_error: 0.2847 - mean_absolute_error: 0.3260 - val_loss: 0.3118 - val_mean_squared_error: 0.2982 - val_mean_absolute_error: 0.3118
# Epoch 7/40
# 519/519 [==============================] - 0s 193us/step - loss: 0.2379 - mean_squared_error: 0.1930 - mean_absolute_error: 0.2701 - val_loss: 0.2710 - val_mean_squared_error: 0.2567 - val_mean_absolute_error: 0.2710
# Epoch 8/40
# 519/519 [==============================] - 0s 200us/step - loss: 0.2069 - mean_squared_error: 0.1708 - mean_absolute_error: 0.2351 - val_loss: 0.2617 - val_mean_squared_error: 0.2640 - val_mean_absolute_error: 0.2617
# Epoch 9/40
# 519/519 [==============================] - 0s 202us/step - loss: 0.1954 - mean_squared_error: 0.1579 - mean_absolute_error: 0.2216 - val_loss: 0.2435 - val_mean_squared_error: 0.2402 - val_mean_absolute_error: 0.2435
# Epoch 10/40
# 519/519 [==============================] - 0s 200us/step - loss: 0.1833 - mean_squared_error: 0.1440 - mean_absolute_error: 0.2082 - val_loss: 0.2294 - val_mean_squared_error: 0.2124 - val_mean_absolute_error: 0.2294
# Epoch 11/40
# 519/519 [==============================] - 0s 202us/step - loss: 0.1719 - mean_squared_error: 0.1228 - mean_absolute_error: 0.1950 - val_loss: 0.2290 - val_mean_squared_error: 0.2010 - val_mean_absolute_error: 0.2290
# Epoch 12/40
# 519/519 [==============================] - 0s 201us/step - loss: 0.1635 - mean_squared_error: 0.1185 - mean_absolute_error: 0.1854 - val_loss: 0.2272 - val_mean_squared_error: 0.2093 - val_mean_absolute_error: 0.2272
# Epoch 13/40
# 519/519 [==============================] - 0s 201us/step - loss: 0.1612 - mean_squared_error: 0.1158 - mean_absolute_error: 0.1825 - val_loss: 0.2193 - val_mean_squared_error: 0.1916 - val_mean_absolute_error: 0.2193
# Epoch 14/40
# 519/519 [==============================] - 0s 201us/step - loss: 0.1576 - mean_squared_error: 0.1055 - mean_absolute_error: 0.1782 - val_loss: 0.2129 - val_mean_squared_error: 0.1825 - val_mean_absolute_error: 0.2129
# Epoch 15/40
# 519/519 [==============================] - 0s 202us/step - loss: 0.1600 - mean_squared_error: 0.1054 - mean_absolute_error: 0.1811 - val_loss: 0.2137 - val_mean_squared_error: 0.1809 - val_mean_absolute_error: 0.2137
# Epoch 16/40
# 519/519 [==============================] - 0s 201us/step - loss: 0.1528 - mean_squared_error: 0.1011 - mean_absolute_error: 0.1725 - val_loss: 0.2182 - val_mean_squared_error: 0.1856 - val_mean_absolute_error: 0.2182
# Epoch 17/40
# Epoch 31/40
# 519/519 [==============================] - 0s 196us/step - loss: 0.1313 - mean_squared_error: 0.0740 - mean_absolute_error: 0.1483 - val_loss: 0.1937 - val_mean_squared_error: 0.1279 - val_mean_absolute_error: 0.1937
# Epoch 32/40
# 519/519 [==============================] - 0s 201us/step - loss: 0.1288 - mean_squared_error: 0.0748 - mean_absolute_error: 0.1453 - val_loss: 0.1895 - val_mean_squared_error: 0.1373 - val_mean_absolute_error: 0.1895
# Epoch 33/40
# 519/519 [==============================] - 0s 203us/step - loss: 0.1270 - mean_squared_error: 0.0757 - mean_absolute_error: 0.1434 - val_loss: 0.1923 - val_mean_squared_error: 0.1244 - val_mean_absolute_error: 0.1923
# Epoch 34/40
# 519/519 [==============================] - 0s 205us/step - loss: 0.1266 - mean_squared_error: 0.0665 - mean_absolute_error: 0.1428 - val_loss: 0.1859 - val_mean_squared_error: 0.1207 - val_mean_absolute_error: 0.1859
# Epoch 35/40
# 519/519 [==============================] - 0s 201us/step - loss: 0.1232 - mean_squared_error: 0.0683 - mean_absolute_error: 0.1389 - val_loss: 0.1904 - val_mean_squared_error: 0.1185 - val_mean_absolute_error: 0.1904
# Epoch 36/40
# 519/519 [==============================] - 0s 198us/step - loss: 0.1296 - mean_squared_error: 0.0681 - mean_absolute_error: 0.1462 - val_loss: 0.1827 - val_mean_squared_error: 0.1093 - val_mean_absolute_error: 0.1827
# Epoch 37/40
# 519/519 [==============================] - 0s 197us/step - loss: 0.1212 - mean_squared_error: 0.0609 - mean_absolute_error: 0.1366 - val_loss: 0.1776 - val_mean_squared_error: 0.1120 - val_mean_absolute_error: 0.1776
# Epoch 38/40
# 519/519 [==============================] - 0s 200us/step - loss: 0.1192 - mean_squared_error: 0.0653 - mean_absolute_error: 0.1344 - val_loss: 0.1762 - val_mean_squared_error: 0.1098 - val_mean_absolute_error: 0.1762
# Epoch 39/40
# 519/519 [==============================] - 0s 199us/step - loss: 0.1161 - mean_squared_error: 0.0599 - mean_absolute_error: 0.1309 - val_loss: 0.1783 - val_mean_squared_error: 0.1117 - val_mean_absolute_error: 0.1783
# Epoch 40/40
# 519/519 [==============================] - 0s 198us/step - loss: 0.1195 - mean_squared_error: 0.0626 - mean_absolute_error: 0.1348 - val_loss: 0.1803 - val_mean_squared_error: 0.1097 - val_mean_absolute_error: 0.1803
# time:  5.572513103485107
# model  2 , config:  (0.001, 200, 0.8)
# Train on 519 samples, validate on 130 samples
# Epoch 1/40
# 519/519 [==============================] - 1s 2ms/step - loss: 0.6078 - mean_squared_error: 1.1760 - mean_absolute_error: 0.6897 - val_loss: 0.6260 - val_mean_squared_error: 1.0655 - val_mean_absolute_error: 0.6260
# Epoch 2/40
# 519/519 [==============================] - 0s 238us/step - loss: 0.4367 - mean_squared_error: 0.5921 - mean_absolute_error: 0.4947 - val_loss: 0.4437 - val_mean_squared_error: 0.4974 - val_mean_absolute_error: 0.4437
# Epoch 3/40
# Epoch 30/40
# 519/519 [==============================] - 0s 246us/step - loss: 0.1158 - mean_squared_error: 0.0560 - mean_absolute_error: 0.1306 - val_loss: 0.1845 - val_mean_squared_error: 0.1114 - val_mean_absolute_error: 0.1845
# Epoch 31/40
# 519/519 [==============================] - 0s 246us/step - loss: 0.1202 - mean_squared_error: 0.0647 - mean_absolute_error: 0.1356 - val_loss: 0.1769 - val_mean_squared_error: 0.1003 - val_mean_absolute_error: 0.1769
# Epoch 32/40
# 519/519 [==============================] - 0s 249us/step - loss: 0.1144 - mean_squared_error: 0.0561 - mean_absolute_error: 0.1292 - val_loss: 0.1762 - val_mean_squared_error: 0.0963 - val_mean_absolute_error: 0.1762
# Epoch 33/40
# 519/519 [==============================] - 0s 246us/step - loss: 0.1119 - mean_squared_error: 0.0541 - mean_absolute_error: 0.1263 - val_loss: 0.1702 - val_mean_squared_error: 0.0884 - val_mean_absolute_error: 0.1702
# Epoch 34/40
# 519/519 [==============================] - 0s 241us/step - loss: 0.1096 - mean_squared_error: 0.0517 - mean_absolute_error: 0.1237 - val_loss: 0.1718 - val_mean_squared_error: 0.0899 - val_mean_absolute_error: 0.1718
# Epoch 35/40
# 519/519 [==============================] - 0s 241us/step - loss: 0.1088 - mean_squared_error: 0.0533 - mean_absolute_error: 0.1229 - val_loss: 0.1684 - val_mean_squared_error: 0.0841 - val_mean_absolute_error: 0.1684
# Epoch 36/40
# 519/519 [==============================] - 0s 240us/step - loss: 0.1095 - mean_squared_error: 0.0497 - mean_absolute_error: 0.1235 - val_loss: 0.1664 - val_mean_squared_error: 0.0865 - val_mean_absolute_error: 0.1664
# Epoch 37/40
# 519/519 [==============================] - 0s 241us/step - loss: 0.1125 - mean_squared_error: 0.0564 - mean_absolute_error: 0.1271 - val_loss: 0.1798 - val_mean_squared_error: 0.0855 - val_mean_absolute_error: 0.1798
# Epoch 38/40
# 519/519 [==============================] - 0s 240us/step - loss: 0.1190 - mean_squared_error: 0.0530 - mean_absolute_error: 0.1344 - val_loss: 0.1722 - val_mean_squared_error: 0.0848 - val_mean_absolute_error: 0.1722
# Epoch 39/40
# 519/519 [==============================] - 0s 240us/step - loss: 0.1143 - mean_squared_error: 0.0541 - mean_absolute_error: 0.1288 - val_loss: 0.1716 - val_mean_squared_error: 0.0801 - val_mean_absolute_error: 0.1716
# Epoch 40/40
# 519/519 [==============================] - 0s 247us/step - loss: 0.1107 - mean_squared_error: 0.0481 - mean_absolute_error: 0.1247 - val_loss: 0.1647 - val_mean_squared_error: 0.0785 - val_mean_absolute_error: 0.1647
# time:  6.776508808135986
# model  3 , config:  (0.001, 300, 0.8)
# Train on 519 samples, validate on 130 samples
# Epoch 1/40
# 519/519 [==============================] - 1s 2ms/step - loss: 0.6090 - mean_squared_error: 1.1464 - mean_absolute_error: 0.6892 - val_loss: 0.5808 - val_mean_squared_error: 0.9848 - val_mean_absolute_error: 0.5808
# Epoch 2/40
# 519/519 [==============================] - 0s 321us/step - loss: 0.3980 - mean_squared_error: 0.5218 - mean_absolute_error: 0.4502 - val_loss: 0.3804 - val_mean_squared_error: 0.3670 - val_mean_absolute_error: 0.3804
# Epoch 3/40
# 519/519 [==============================] - 0s 343us/step - loss: 0.2986 - mean_squared_error: 0.2780 - mean_absolute_error: 0.3383 - val_loss: 0.3039 - val_mean_squared_error: 0.2515 - val_mean_absolute_error: 0.3039
# Epoch 4/40
# 519/519 [==============================] - 0s 346us/step - loss: 0.2450 - mean_squared_error: 0.2001 - mean_absolute_error: 0.2773 - val_loss: 0.2823 - val_mean_squared_error: 0.2288 - val_mean_absolute_error: 0.2823
# Epoch 5/40
# 519/519 [==============================] - 0s 327us/step - loss: 0.2155 - mean_squared_error: 0.1477 - mean_absolute_error: 0.2433 - val_loss: 0.2396 - val_mean_squared_error: 0.1727 - val_mean_absolute_error: 0.2396
# Epoch 6/40
# 519/519 [==============================] - 0s 322us/step - loss: 0.1779 - mean_squared_error: 0.1120 - mean_absolute_error: 0.2013 - val_loss: 0.2469 - val_mean_squared_error: 0.1574 - val_mean_absolute_error: 0.2469
# Epoch 7/40
# 519/519 [==============================] - 0s 331us/step - loss: 0.1806 - mean_squared_error: 0.1066 - mean_absolute_error: 0.2042 - val_loss: 0.2402 - val_mean_squared_error: 0.1503 - val_mean_absolute_error: 0.2402
# Epoch 8/40
# ...
# Epoch 12/40
# 519/519 [==============================] - 0s 216us/step - loss: 0.1546 - mean_squared_error: 0.0884 - mean_absolute_error: 0.1752 - val_loss: 0.2050 - val_mean_squared_error: 0.1188 - val_mean_absolute_error: 0.2050
# Epoch 13/40
# 519/519 [==============================] - 0s 219us/step - loss: 0.1493 - mean_squared_error: 0.0810 - mean_absolute_error: 0.1693 - val_loss: 0.1943 - val_mean_squared_error: 0.1161 - val_mean_absolute_error: 0.1943
# Epoch 14/40
# 519/519 [==============================] - 0s 217us/step - loss: 0.1465 - mean_squared_error: 0.0879 - mean_absolute_error: 0.1661 - val_loss: 0.1943 - val_mean_squared_error: 0.1202 - val_mean_absolute_error: 0.1943
# Epoch 15/40
# 519/519 [==============================] - 0s 217us/step - loss: 0.1407 - mean_squared_error: 0.0878 - mean_absolute_error: 0.1594 - val_loss: 0.1944 - val_mean_squared_error: 0.1092 - val_mean_absolute_error: 0.1944
# Epoch 16/40
# 519/519 [==============================] - 0s 219us/step - loss: 0.1372 - mean_squared_error: 0.0760 - mean_absolute_error: 0.1552 - val_loss: 0.1937 - val_mean_squared_error: 0.1112 - val_mean_absolute_error: 0.1937
# Epoch 17/40
# 519/519 [==============================] - 0s 222us/step - loss: 0.1395 - mean_squared_error: 0.0783 - mean_absolute_error: 0.1579 - val_loss: 0.1963 - val_mean_squared_error: 0.1097 - val_mean_absolute_error: 0.1963
# Epoch 18/40
# 519/519 [==============================] - 0s 226us/step - loss: 0.1366 - mean_squared_error: 0.0737 - mean_absolute_error: 0.1543 - val_loss: 0.1853 - val_mean_squared_error: 0.1012 - val_mean_absolute_error: 0.1853
# Epoch 19/40
# 519/519 [==============================] - 0s 227us/step - loss: 0.1367 - mean_squared_error: 0.0719 - mean_absolute_error: 0.1547 - val_loss: 0.1882 - val_mean_squared_error: 0.1072 - val_mean_absolute_error: 0.1882
# Epoch 33/40
# 519/519 [==============================] - 0s 228us/step - loss: 0.1182 - mean_squared_error: 0.0570 - mean_absolute_error: 0.1336 - val_loss: 0.1732 - val_mean_squared_error: 0.0859 - val_mean_absolute_error: 0.1732
# Epoch 34/40
# 519/519 [==============================] - 0s 221us/step - loss: 0.1215 - mean_squared_error: 0.0618 - mean_absolute_error: 0.1376 - val_loss: 0.1677 - val_mean_squared_error: 0.0843 - val_mean_absolute_error: 0.1677
# Epoch 35/40
# 519/519 [==============================] - 0s 218us/step - loss: 0.1160 - mean_squared_error: 0.0574 - mean_absolute_error: 0.1314 - val_loss: 0.1699 - val_mean_squared_error: 0.0823 - val_mean_absolute_error: 0.1699
# Epoch 36/40
# 519/519 [==============================] - 0s 217us/step - loss: 0.1165 - mean_squared_error: 0.0616 - mean_absolute_error: 0.1322 - val_loss: 0.1672 - val_mean_squared_error: 0.0853 - val_mean_absolute_error: 0.1672
# Epoch 37/40
# 519/519 [==============================] - 0s 217us/step - loss: 0.1149 - mean_squared_error: 0.0543 - mean_absolute_error: 0.1300 - val_loss: 0.1655 - val_mean_squared_error: 0.0788 - val_mean_absolute_error: 0.1655
# Epoch 38/40
# 519/519 [==============================] - 0s 218us/step - loss: 0.1106 - mean_squared_error: 0.0515 - mean_absolute_error: 0.1253 - val_loss: 0.1627 - val_mean_squared_error: 0.0794 - val_mean_absolute_error: 0.1627
# Epoch 39/40
# 519/519 [==============================] - 0s 217us/step - loss: 0.1096 - mean_squared_error: 0.0482 - mean_absolute_error: 0.1240 - val_loss: 0.1632 - val_mean_squared_error: 0.0806 - val_mean_absolute_error: 0.1632
# Epoch 40/40
# 519/519 [==============================] - 0s 216us/step - loss: 0.1109 - mean_squared_error: 0.0495 - mean_absolute_error: 0.1254 - val_loss: 0.1612 - val_mean_squared_error: 0.0787 - val_mean_absolute_error: 0.1612
# time:  6.435917854309082
# model  3 , config:  (0.001, 300, 0.8)
# Train on 519 samples, validate on 130 samples
# Epoch 1/40
# 519/519 [==============================] - 1s 2ms/step - loss: 0.6590 - mean_squared_error: 1.3371 - mean_absolute_error: 0.7486 - val_loss: 0.5150 - val_mean_squared_error: 0.7385 - val_mean_absolute_error: 0.5150
# Epoch 2/40
# 519/519 [==============================] - 0s 321us/step - loss: 0.4029 - mean_squared_error: 0.5528 - mean_absolute_error: 0.4577 - val_loss: 0.3949 - val_mean_squared_error: 0.3925 - val_mean_absolute_error: 0.3949
# Epoch 3/40
# 519/519 [==============================] - 0s 321us/step - loss: 0.3172 - mean_squared_error: 0.3310 - mean_absolute_error: 0.3620 - val_loss: 0.3339 - val_mean_squared_error: 0.2783 - val_mean_absolute_error: 0.3339
# Epoch 4/40
# 519/519 [==============================] - 0s 333us/step - loss: 0.2446 - mean_squared_error: 0.1817 - mean_absolute_error: 0.2777 - val_loss: 0.2696 - val_mean_squared_error: 0.1874 - val_mean_absolute_error: 0.2696
# Epoch 5/40
# 519/519 [==============================] - 0s 341us/step - loss: 0.2079 - mean_squared_error: 0.1409 - mean_absolute_error: 0.2357 - val_loss: 0.2553 - val_mean_squared_error: 0.1858 - val_mean_absolute_error: 0.2553
# Epoch 6/40
# 519/519 [==============================] - 0s 322us/step - loss: 0.2063 - mean_squared_error: 0.1504 - mean_absolute_error: 0.2343 - val_loss: 0.2330 - val_mean_squared_error: 0.1594 - val_mean_absolute_error: 0.2330
# Epoch 7/40
# 519/519 [==============================] - 0s 323us/step - loss: 0.1786 - mean_squared_error: 0.1036 - mean_absolute_error: 0.2020 - val_loss: 0.2218 - val_mean_squared_error: 0.1325 - val_mean_absolute_error: 0.2218
# Epoch 8/40
# 519/519 [==============================] - 0s 328us/step - loss: 0.1664 - mean_squared_error: 0.0908 - mean_absolute_error: 0.1884 - val_loss: 0.2183 - val_mean_squared_error: 0.1331 - val_mean_absolute_error: 0.2183
# Epoch 9/40
# 519/519 [==============================] - 0s 324us/step - loss: 0.1610 - mean_squared_error: 0.0903 - mean_absolute_error: 0.1819 - val_loss: 0.1995 - val_mean_squared_error: 0.1163 - val_mean_absolute_error: 0.1995
# Epoch 10/40
# 519/519 [==============================] - 0s 324us/step - loss: 0.1579 - mean_squared_error: 0.0799 - mean_absolute_error: 0.1790 - val_loss: 0.2202 - val_mean_squared_error: 0.1276 - val_mean_absolute_error: 0.2202
# Epoch 11/40
# 519/519 [==============================] - 0s 332us/step - loss: 0.1603 - mean_squared_error: 0.0886 - mean_absolute_error: 0.1810 - val_loss: 0.2180 - val_mean_squared_error: 0.1240 - val_mean_absolute_error: 0.2180
# Epoch 12/40
# 519/519 [==============================] - 0s 331us/step - loss: 0.1618 - mean_squared_error: 0.0846 - mean_absolute_error: 0.1827 - val_loss: 0.2202 - val_mean_squared_error: 0.1310 - val_mean_absolute_error: 0.2202
# Epoch 13/40
# 519/519 [==============================] - 0s 332us/step - loss: 0.1583 - mean_squared_error: 0.0828 - mean_absolute_error: 0.1787 - val_loss: 0.2056 - val_mean_squared_error: 0.1134 - val_mean_absolute_error: 0.2056
# Epoch 14/40
# 519/519 [==============================] - 0s 324us/step - loss: 0.1685 - mean_squared_error: 0.0895 - mean_absolute_error: 0.1910 - val_loss: 0.1967 - val_mean_squared_error: 0.1199 - val_mean_absolute_error: 0.1967
# Epoch 15/40
# 519/519 [==============================] - 0s 328us/step - loss: 0.1508 - mean_squared_error: 0.0875 - mean_absolute_error: 0.1702 - val_loss: 0.1874 - val_mean_squared_error: 0.1053 - val_mean_absolute_error: 0.1874
# Epoch 16/40
# 519/519 [==============================] - 0s 320us/step - loss: 0.1424 - mean_squared_error: 0.0782 - mean_absolute_error: 0.1614 - val_loss: 0.1849 - val_mean_squared_error: 0.1043 - val_mean_absolute_error: 0.1849
# Epoch 17/40
# 519/519 [==============================] - 0s 321us/step - loss: 0.1358 - mean_squared_error: 0.0685 - mean_absolute_error: 0.1537 - val_loss: 0.1910 - val_mean_squared_error: 0.1046 - val_mean_absolute_error: 0.1910
# Epoch 18/40
# 519/519 [==============================] - 0s 325us/step - loss: 0.1343 - mean_squared_error: 0.0699 - mean_absolute_error: 0.1521 - val_loss: 0.1849 - val_mean_squared_error: 0.1030 - val_mean_absolute_error: 0.1849
# Epoch 19/40
# 519/519 [==============================] - 0s 325us/step - loss: 0.1348 - mean_squared_error: 0.0687 - mean_absolute_error: 0.1522 - val_loss: 0.1880 - val_mean_squared_error: 0.0999 - val_mean_absolute_error: 0.1880
# Epoch 20/40
# 519/519 [==============================] - 0s 320us/step - loss: 0.1330 - mean_squared_error: 0.0678 - mean_absolute_error: 0.1503 - val_loss: 0.1813 - val_mean_squared_error: 0.0899 - val_mean_absolute_error: 0.1813
# Epoch 21/40
# 519/519 [==============================] - 0s 323us/step - loss: 0.1290 - mean_squared_error: 0.0592 - mean_absolute_error: 0.1458 - val_loss: 0.1733 - val_mean_squared_error: 0.0867 - val_mean_absolute_error: 0.1733
# Epoch 22/40
# 519/519 [==============================] - 0s 333us/step - loss: 0.1207 - mean_squared_error: 0.0546 - mean_absolute_error: 0.1362 - val_loss: 0.1718 - val_mean_squared_error: 0.0841 - val_mean_absolute_error: 0.1718
# Epoch 23/40
# 519/519 [==============================] - 0s 322us/step - loss: 0.1215 - mean_squared_error: 0.0541 - mean_absolute_error: 0.1370 - val_loss: 0.1742 - val_mean_squared_error: 0.0864 - val_mean_absolute_error: 0.1742
# Epoch 24/40
# 519/519 [==============================] - 0s 326us/step - loss: 0.1204 - mean_squared_error: 0.0539 - mean_absolute_error: 0.1356 - val_loss: 0.1730 - val_mean_squared_error: 0.0886 - val_mean_absolute_error: 0.1730
# Epoch 25/40
# 519/519 [==============================] - 0s 330us/step - loss: 0.1193 - mean_squared_error: 0.0529 - mean_absolute_error: 0.1344 - val_loss: 0.1754 - val_mean_squared_error: 0.0907 - val_mean_absolute_error: 0.1754
# Epoch 26/40
# 519/519 [==============================] - 0s 342us/step - loss: 0.1214 - mean_squared_error: 0.0584 - mean_absolute_error: 0.1370 - val_loss: 0.1716 - val_mean_squared_error: 0.0853 - val_mean_absolute_error: 0.1716
# Epoch 27/40
# 519/519 [==============================] - 0s 373us/step - loss: 0.1179 - mean_squared_error: 0.0534 - mean_absolute_error: 0.1332 - val_loss: 0.1678 - val_mean_squared_error: 0.0822 - val_mean_absolute_error: 0.1678
# Epoch 28/40
# 519/519 [==============================] - 0s 346us/step - loss: 0.1204 - mean_squared_error: 0.0531 - mean_absolute_error: 0.1361 - val_loss: 0.1668 - val_mean_squared_error: 0.0800 - val_mean_absolute_error: 0.1668
# Epoch 29/40
# 519/519 [==============================] - 0s 319us/step - loss: 0.1135 - mean_squared_error: 0.0493 - mean_absolute_error: 0.1283 - val_loss: 0.1649 - val_mean_squared_error: 0.0796 - val_mean_absolute_error: 0.1649
# Epoch 30/40
# 519/519 [==============================] - 0s 325us/step - loss: 0.1143 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1293 - val_loss: 0.1717 - val_mean_squared_error: 0.0860 - val_mean_absolute_error: 0.1717
# Epoch 31/40
# 519/519 [==============================] - 0s 328us/step - loss: 0.1211 - mean_squared_error: 0.0583 - mean_absolute_error: 0.1371 - val_loss: 0.1663 - val_mean_squared_error: 0.0807 - val_mean_absolute_error: 0.1663
# Epoch 32/40
# 519/519 [==============================] - 0s 330us/step - loss: 0.1170 - mean_squared_error: 0.0514 - mean_absolute_error: 0.1322 - val_loss: 0.1651 - val_mean_squared_error: 0.0818 - val_mean_absolute_error: 0.1651
# Epoch 33/40
# 519/519 [==============================] - 0s 330us/step - loss: 0.1101 - mean_squared_error: 0.0472 - mean_absolute_error: 0.1245 - val_loss: 0.1622 - val_mean_squared_error: 0.0767 - val_mean_absolute_error: 0.1622
# Epoch 34/40
# 519/519 [==============================] - 0s 332us/step - loss: 0.1108 - mean_squared_error: 0.0614 - mean_absolute_error: 0.1253 - val_loss: 0.1597 - val_mean_squared_error: 0.0785 - val_mean_absolute_error: 0.1597
# Epoch 35/40
# 519/519 [==============================] - 0s 336us/step - loss: 0.1075 - mean_squared_error: 0.0461 - mean_absolute_error: 0.1215 - val_loss: 0.1613 - val_mean_squared_error: 0.0813 - val_mean_absolute_error: 0.1613
# Epoch 36/40
# 519/519 [==============================] - 0s 344us/step - loss: 0.1121 - mean_squared_error: 0.0464 - mean_absolute_error: 0.1268 - val_loss: 0.1668 - val_mean_squared_error: 0.0828 - val_mean_absolute_error: 0.1668
# Epoch 37/40
# 519/519 [==============================] - 0s 341us/step - loss: 0.1084 - mean_squared_error: 0.0455 - mean_absolute_error: 0.1223 - val_loss: 0.1632 - val_mean_squared_error: 0.0825 - val_mean_absolute_error: 0.1632
# Epoch 38/40
# 519/519 [==============================] - 0s 341us/step - loss: 0.1091 - mean_squared_error: 0.0459 - mean_absolute_error: 0.1229 - val_loss: 0.1753 - val_mean_squared_error: 0.0935 - val_mean_absolute_error: 0.1753
# Epoch 39/40
# 519/519 [==============================] - 0s 336us/step - loss: 0.1127 - mean_squared_error: 0.0471 - mean_absolute_error: 0.1274 - val_loss: 0.1602 - val_mean_squared_error: 0.0770 - val_mean_absolute_error: 0.1602
# Epoch 40/40
# 519/519 [==============================] - 0s 335us/step - loss: 0.1065 - mean_squared_error: 0.0506 - mean_absolute_error: 0.1201 - val_loss: 0.1682 - val_mean_squared_error: 0.0840 - val_mean_absolute_error: 0.1682
# time:  8.683385610580444

# %% [markdown]
# ### select hyperparam uni

# %%
#Select best hyperparameters
with open(path_save_optimize+"model_infos.pkl", 'rb') as f:
    my_model = pickle.load(f)
with open(path_save_optimize+"cvgridsearch.pkl", 'rb') as f:
    CvGridResLoc = pickle.load(f)

hyperparams_array=np.zeros((len(my_model["list_drop"]),len(my_model["list_neurones"]),len(my_model["list_forget"]),len(my_model["list_epoch"]),4))
grid_val = np.zeros((len(my_model["list_drop"]),len(my_model["list_neurones"]),len(my_model["list_forget"]),len(my_model["list_epoch"]),my_model["n_split"]))
grid = np.zeros((len(my_model["list_drop"]),len(my_model["list_neurones"]),len(my_model["list_forget"]),len(my_model["list_epoch"]),my_model["n_split"]))
#grid_epoch = np.zeros((len(my_model["list_drop"]),len(my_model["list_neurones"]),len(my_model["list_forget"]),my_model["n_split"]))


hyperparams_re = [my_model["list_drop"],my_model["list_neurones"],my_model["list_forget"],my_model["list_epoch"]]
for ns in range(len(CvGridResLoc)):
    for config in itertools.product(*hyperparams_re):
        i=(config[0]==np.array(my_model["list_drop"])).argmax()
        j=(config[1]==np.array(my_model["list_neurones"])).argmax()
        k=(config[2]==np.array(my_model["list_forget"])).argmax()
        l=(config[3]==np.array(my_model["list_epoch"])).argmax()
        hyperparams_array[i,j,k,l]=np.array(config)
        grid_val[i,j,k,l,ns]=CvGridResLoc[ns][config]['history']['val_mean_absolute_error'][config[3]-1]
        grid[i,j,k,l,ns]=CvGridResLoc[ns][config]['history']['mean_absolute_error'][config[3]-1]
      
    
mask_min = (grid_val.mean(axis=4).min()==grid_val.mean(axis=4))


my_model["grid_val"]  = grid_val
my_model["grid"]  = grid
my_model["best_drop"]  = hyperparams_array[mask_min][0][0]
my_model["best_neurones"]  = int(hyperparams_array[mask_min][0][1])
my_model["best_forget"] = hyperparams_array[mask_min][0][2]
my_model["best_epoch"] = int(hyperparams_array[mask_min][0][3])

PickleRick(path=my_model["path_save_optimize"],name="model_infos.pkl",obj=my_model,force=True)

# %%
import seaborn as sns
sns.set_style('whitegrid')
bres=[[],[]]
for i,j in enumerate(CvGridResLoc):
    
    filt=j[(my_model["best_drop"] ,my_model["best_neurones"],my_model["best_forget"],my_model["best_epoch"])]
    bres[0].append(filt['history']['mean_absolute_error'])
    bres[1].append(filt['history']['val_mean_absolute_error'])
bres = np.array(bres).mean(axis=1)



f=plt.plot(range(1,max(my_model['list_epoch'])+1),bres[0],range(1,max(my_model['list_epoch'])+1),bres[1])
plt.title('MAE Train / VAL ')
plt.legend(['ensemble d\'apprentissage','ensemble de validation'])
plt.show()


bres=[[],[]]
for i,j in enumerate(CvGridResLoc):
    filt=j[(my_model["best_drop"] ,my_model["best_neurones"],my_model["best_forget"],my_model["best_epoch"])]
    bres[0].append(filt['history']['mean_squared_error'])
    bres[1].append(filt['history']['val_mean_squared_error'])
bres = np.array(bres).mean(axis=1)


f=plt.plot(range(1,max(my_model['list_epoch'])+1),bres[0],range(1,max(my_model['list_epoch'])+1),bres[1])
plt.title('MSE Train / VAL ')
plt.legend(['ensemble d\'apprentissage','ensemble de validation'])
plt.show()

# %% [markdown]
# ## Learn and predict UNI

# %%
with open(path_save_optimize+"model_infos.pkl", 'rb') as f:
    my_model = pickle.load(f)
    
start_date_train_list=["2014-01-01","2014-01-01","2014-01-01","2014-01-01"]
end_date_train_list=["2015-01-01","2015-04-01","2015-07-01","2015-10-01"]

start_date_train_list=["2015-01-01",]
end_date_train_list=["2017-01-01",]


for i,j in zip(start_date_train_list, end_date_train_list):
    
    DatavPred,DatacPred=None,None
    XvPred,YvPred,XcPred,YcPred=None,None,None,None,
    DatavTrain,DatacTrain=None,None
    XvTrain,YvTrain,Xco,Yco=None,None,None,None,
    
    DatavTrain=X[my_model['time_series']][i:j].values
    DatacTrain=X[my_model['features_tminuslag_t0']][i:j].values
    
    # normalisation
    norm=my_model['norm']
    scaler = my_model["scaler"]
    if norm:
        #scaler = MinMaxScaler(feature_range=[0,1])
        #DatavTrainS = scaler.fit_transform(DatavTrain.astype(float))
        mean_train =  DatavTrain.mean(axis=0)
        my_model["mean_train"]= mean_train
        DatavTrainS = DatavTrain/mean_train
        #scaler = StandardScaler()
       # DatavTrainS = scaler.fit_transform(DatavTrain.astype(float))
    else:
        DatavTrainS = DatavTrain
        
    # one hot encoder contextual values
    enc = my_model["encoder"]
    DatacTrainOh = np.array(enc.transform(DatacTrain).todense())



    XvTrain,YvTrain=create_xy_dense(DatavTrainS,look_back=my_model["lag_window"])
    XcTrain,YcTrain=create_xy_dense(DatacTrainOh,look_back=my_model["lag_window"])
    


    ml = buildGRUUNI(my_model["best_drop"] ,int(my_model["best_neurones"]), my_model["lag_window"],
                        len(my_model["time_series"]),YcTrain.shape[1])
    ml.compile(optimizer='adam',loss='mae',metrics=['mse','mae'],sample_weight_mode=None)
    w = np.linspace(1,my_model["best_forget"],XvTrain.shape[0])
    #w = np.reshape(np.repeat(np.flip(w,0),my_model['lag_window']),(w.shape[0],my_model['lag_window']))
    h = ml.fit([XvTrain,XcTrain,YcTrain],YvTrain,epochs=my_model['best_epoch'],sample_weight=w,batch_size=my_model["batch_size"])
    
    def reload_model(weights, my_model):
        m = my_model['function_model'](my_model["best_drop"] ,int(my_model["best_neurones"]), my_model["lag_window"],
                        len(my_model["time_series"]),my_model['YcTrain_shape1'])
        m.compile(optimizer='adam',loss='mae',metrics=['mse','mae'],sample_weight_mode=None)
        m.set_weights(weights)
        return m
    
    my_model['YcTrain_shape1'] = YcTrain.shape[1]
    my_model['reload_model'] = reload_model
    PickleRick(path=my_model["path_save_fit"]+i+"_"+j+"/",name="model_infos.pkl",obj=my_model,force=True)
    
    if not os.path.exists(my_model["path_save_fit"]+i+"_"+j+"/"):
        os.makedirs(my_model["path_save_fit"]+i+"_"+j+"/")
    weights=ml.get_weights()
    output_filename = my_model["path_save_fit"]+i+"_"+j+"/"+ 'weights.npy'
    np.save(output_filename, weights)
        
    #PREDICTION    
    start_date_pred = "2015-01-01"
    end_date_pred = "2018-01-01"
    
    XvTrain,YvTrain,Xco,Yco=None,None,None,None,
    DatavTrain,DatacTrain=None,None
    DatavPred=X[my_model['time_series']][start_date_pred:end_date_pred].values
    DatacPred=X[my_model['features_tminuslag_t0']][start_date_pred:end_date_pred].values
    DatePred=X[my_model['time_series']][start_date_pred:end_date_pred].index.values
    
    norm = my_model['norm']
    scaler = None
    if norm:
        DatavPredS = DatavPred/my_model['mean_train']
    else: 
        DatavPredS = DatavPred

    # one hot encoder contextual values
    enc = my_model["encoder"]
    DatacPredOh = np.array(enc.transform(DatacPred).todense())


    XvPred,YvPred=create_xy_dense(DatavPredS,look_back=my_model["lag_window"])
    XcPred,YcPred=create_xy_dense(DatacPredOh,look_back=my_model["lag_window"])
    XDate,YDate=create_xy_dense(DatePred,look_back=my_model["lag_window"])
    YDate=YDate.ravel()
    
    t1=time.time()
    prediction = ml.predict([XvPred,XcPred,YcPred],verbose=1)
    print("Time prediction: ",time.time()-t1)
    #prediction = np.reshape(prediction,(prediction.shape[0]*prediction.shape[1],prediction.shape[2]))
    prediction = my_model["mean_train"]*prediction
    df_pred = pd.DataFrame()
    df_pred["Datetime"]=YDate
    for ix,id_ in enumerate(my_model["time_series"]):
        df_pred[id_]=prediction[:,ix]
    try:
        df_pred.to_csv(path_save_prediction+i+"_"+j+".csv",index=False,float_format='%.3f')
    except:
        os.makedirs(path_save_prediction)
        df_pred.to_csv(path_save_prediction+i+"_"+j+".csv",index=False,float_format='%.3f')
# Out:
# Epoch 1/40
# 649/649 [==============================] - 1s 2ms/step - loss: 0.5992 - mean_squared_error: 1.1194 - mean_absolute_error: 0.6800
# Epoch 2/40
# 649/649 [==============================] - 0s 295us/step - loss: 0.3930 - mean_squared_error: 0.5507 - mean_absolute_error: 0.4460
# Epoch 3/40
# 649/649 [==============================] - 0s 278us/step - loss: 0.3321 - mean_squared_error: 0.3340 - mean_absolute_error: 0.3784
# Epoch 4/40
# 649/649 [==============================] - 0s 278us/step - loss: 0.2400 - mean_squared_error: 0.1822 - mean_absolute_error: 0.2722
# Epoch 5/40
# 649/649 [==============================] - 0s 284us/step - loss: 0.2008 - mean_squared_error: 0.1353 - mean_absolute_error: 0.2276
# Epoch 6/40
# 649/649 [==============================] - 0s 286us/step - loss: 0.1758 - mean_squared_error: 0.1108 - mean_absolute_error: 0.1993
# Epoch 7/40
# 649/649 [==============================] - 0s 289us/step - loss: 0.1673 - mean_squared_error: 0.0972 - mean_absolute_error: 0.1898
# Epoch 8/40
# 649/649 [==============================] - 0s 287us/step - loss: 0.1562 - mean_squared_error: 0.0915 - mean_absolute_error: 0.1765
# Epoch 9/40
# 649/649 [==============================] - 0s 275us/step - loss: 0.1536 - mean_squared_error: 0.0863 - mean_absolute_error: 0.1736
# Epoch 10/40
# 649/649 [==============================] - 0s 275us/step - loss: 0.1552 - mean_squared_error: 0.0877 - mean_absolute_error: 0.1751
# Epoch 11/40
# 649/649 [==============================] - 0s 277us/step - loss: 0.1437 - mean_squared_error: 0.0794 - mean_absolute_error: 0.1621
# Epoch 12/40
# 649/649 [==============================] - 0s 280us/step - loss: 0.1421 - mean_squared_error: 0.0759 - mean_absolute_error: 0.1602
# Epoch 13/40
# 649/649 [==============================] - 0s 288us/step - loss: 0.1447 - mean_squared_error: 0.0784 - mean_absolute_error: 0.1636
# Epoch 14/40
# 649/649 [==============================] - 0s 287us/step - loss: 0.1414 - mean_squared_error: 0.0685 - mean_absolute_error: 0.1596
# Epoch 15/40
# 649/649 [==============================] - 0s 275us/step - loss: 0.1386 - mean_squared_error: 0.0654 - mean_absolute_error: 0.1565
# Epoch 16/40
# 649/649 [==============================] - 0s 277us/step - loss: 0.1297 - mean_squared_error: 0.0613 - mean_absolute_error: 0.1464
# Epoch 17/40
# 649/649 [==============================] - 0s 277us/step - loss: 0.1240 - mean_squared_error: 0.0570 - mean_absolute_error: 0.1397
# Epoch 18/40
# 649/649 [==============================] - 0s 284us/step - loss: 0.1240 - mean_squared_error: 0.0569 - mean_absolute_error: 0.1397
# Epoch 19/40
# 649/649 [==============================] - 0s 284us/step - loss: 0.1241 - mean_squared_error: 0.0592 - mean_absolute_error: 0.1400
# Epoch 20/40
# 649/649 [==============================] - 0s 302us/step - loss: 0.1215 - mean_squared_error: 0.0566 - mean_absolute_error: 0.1370
